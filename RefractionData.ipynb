# %% [markdown]
# # Plotting Actual Angular Data for Snell's Law
#
# Just a quick plot to show real Snell's Law data.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()
ax = plt.axes()
ax.scatter(thetaincident, thetarefract)
ax.set(xlim=(0, 90), ylim=(0, 50),
       xlabel='angle of incidence', ylabel='angle of refraction',
       title='Refraction Data');

fig.savefig("images/refraction.png")

# %% [markdown]
# If we want to create a single figure with multiple lines, we can simply call the plot function multiple times:
